# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploartion

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 38             2       90             68             42        0  38.2
# 226            0      101             76              0        0  35.7
# 363            4      146             78              0        0  38.5
# 212            7      179             95             31        0  34.2
# 328            2      102             86             36      120  45.5
# 387            8      105            100             36        0  43.3
# 596            0       67             76              0        0  45.3
# 266            0      138              0              0        0  36.3
# 5              5      116             74              0        0  25.6
# 549            4      189            110             31        0  28.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 38                      0.503   27        1
# 226                     0.198   26        0
# 363                     0.520   67        1
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data['Pregnancies'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
data['Glucose'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
data['BloodPressure'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
data['SkinThickness'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
data['Insulin'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
data['BMI'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
data['DiabetesPedigreeFunction'].value_counts().head(17).plot.bar()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(3,3))
plt.pie(data['Outcome'].value_counts(), labels=['No Diabetes','Diabetes'], autopct='%0.f%%')
plt.title('Diabetes Outcome')
plt.show()

# %%
sns.catplot(x="Outcome", y="Age", kind="swarm", data=data)
# Out:
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='Pregnancies', data=data, ax=ax[0])
sns.violinplot(x="Outcome", y='Pregnancies', data=data, ax=ax[1])
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %%
sns.boxplot(x="Outcome", y="Glucose", data=data).set_title('Glucose VS Diabetes')
# Out:
# Text(0.5, 1.0, 'Glucose VS Diabetes')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='BloodPressure', data=data, ax=ax[0]).set_title('BloodPressure VS Diabetes')
sns.violinplot(x="Outcome", y='BloodPressure', data=data, ax=ax[1]).set_title('BloodPressure VS Diabetes')
# Out:
# Text(0.5, 1.0, 'BloodPressure VS Diabetes')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='SkinThickness', data=data, ax=ax[0]).set_title('SkinThickness VS Diabetes')
sns.violinplot(x="Outcome", y='SkinThickness', data=data, ax=ax[1]).set_title('SkinThickness VS Diabetes')
# Out:
# Text(0.5, 1.0, 'SkinThickness VS Diabetes')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='Insulin', data=data, ax=ax[0]).set_title('Insulin VS Diabetes')
sns.violinplot(x="Outcome", y='Insulin', data=data, ax=ax[1]).set_title('Insulin VS Diabetes')
# Out:
# Text(0.5, 1.0, 'Insulin VS Diabetes')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='BMI', data=data, ax=ax[0]).set_title('BMI VS Diabetes')
sns.violinplot(x="Outcome", y='BMI', data=data, ax=ax[1]).set_title('BMI VS Diabetes')
# Out:
# Text(0.5, 1.0, 'BMI VS Diabetes')

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
sns.boxplot(x="Outcome", y='DiabetesPedigreeFunction', data=data, ax=ax[0]).set_title('DiabetesPedigreeFunction VS Diabetes')
sns.violinplot(x="Outcome", y='DiabetesPedigreeFunction', data=data, ax=ax[1]).set_title('DiabetesPedigreeFunction VS Diabetes')
# Out:
# Text(0.5, 1.0, 'DiabetesPedigreeFunction VS Diabetes')

# %% [markdown]
# # Coorelation Matrix Heatmap

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm').set_title('Coorelation Heatmap')
# Out:
# Text(0.5, 1.0, 'Coorelation Heatmap')

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.drop('Outcome',axis=1),data['Outcome'],test_size=0.2,random_state=42)

# %% [markdown]
# # Diabetes Prediction

# %% [markdown]
# Logistic Regression

# %%
#building model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
#training the model
lr.fit(X_train,y_train)
#training accuracy
lr.score(X_train,y_train)
# Out:
# C:\Users\Sam\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7719869706840391

# %%
#predicted outcomes
lr_pred = lr.predict(X_test)

# %% [markdown]
# # Random Forest Classifier

# %%
#buidling model
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100,random_state=42)
rfc
# Out:
# RandomForestClassifier(random_state=42)

# %%
#training model
rfc.fit(X_train, y_train)
#training accuracy
rfc.score(X_train, y_train)
# Out:
# 1.0

# %%
#predicted outcomes
rfc_pred = rfc.predict(X_test)

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
#building model
from sklearn.svm import SVC
svm = SVC(kernel='linear', random_state=0)
svm
# Out:
# SVC(kernel='linear', random_state=0)

# %%
#training the model
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
#training the model
svm.score(X_test, y_test)
# Out:
# 0.7532467532467533

# %%
#predicting outcomes
svm_pred = svm.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %% [raw]
# Evaluating Logistic Regression Model

# %% [markdown]
# # Confusion Matrix Heatmap

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, lr_pred), annot=True, cmap='Blues')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
ax = sns.distplot(y_test, color='r', label='Actual Value',hist=False)
sns.distplot(lr_pred, color='b', label='Predicted Value',hist=False,ax=ax)
plt.title('Actual vs Predicted Value Logistic Regression')
plt.xlabel('Outcome')
plt.ylabel('Count')
# Out:
# C:\Users\Sam\AppData\Local\Temp\ipykernel_1188\268571263.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, color='r', label='Actual Value',hist=False)
# C:\Users\Sam\AppData\Local\Temp\ipykernel_1188\268571263.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Classification

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80        99
#            1       0.64      0.67      0.65        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error
print('Accuracy Score: ',accuracy_score(y_test,lr_pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,lr_pred))
print('Mean Squared Error: ',mean_squared_error(y_test,lr_pred))
# Out:
# Accuracy Score:  0.7467532467532467
# Mean Absolute Error:  0.2532467532467532
# Mean Squared Error:  0.2532467532467532
